# %% [markdown]
# # Lab 01a
#
# This is not the file you are looking for :)
#
# For the introduction to / refresher of PyTorch, refer to [this page](https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) in the official docs.
